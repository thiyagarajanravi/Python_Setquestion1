# %%
# Scenario 1: A system checks if a user is eligible to vote based on their age.
# Write logic to ask the user for their age and determine if they are eligible to vote based on whether they are 18 or older.
# Logic below
# 1. Get age from user
# 2. Check given age is 18 or older
# 3. if yes, get output as "Eligible to Vote"
# 4. if no, get output as "Not Eligible to Vote"

# %%
# Scenario 2: A program processes a list of numbers and needs to find the largest value.
# Write logic to identify and return the largest number from a given list.
# 1. Read the list of numbers
# 2. Check the first number with given numbers in the list one by one
# 3. First number is not a large one, then take the 2nd number to check
# 4. Perform this repitative action until find the largest number in the list
# 5. Once identified largest number, update the largest number
# 6. Return the largest number

# %%
# Scenario 3: A company provides employees with a 10% bonus if their salary exceeds $50,000.
# Write logic to determine the bonus amount based on the given salary.
# 1. Read the employee salary
# 2. Check employee salary exceed $50,000
# 3. if exceed $50,000, calculate 10% bonus
# 4. if not exceed, not eligible for bonus
# 5, return the calculated bonus amount

# %%
# Scenario 4: A program evaluates a number to determine if it is even or odd.
# Write logic to check whether a given number is even or odd.
# 1. Read the given number
# 2. Check given number is odd or Even using modulo operator
# 3. if we get remainder with value, print as "Odd"
# 4. if we get remainder as 0, print as "Even"

# %%
# Scenario 5: A text-processing tool reverses a given word or sentence for formatting purposes.
# Write logic to take a word or sentence as input and produce its reversed version.
# 1. Get text input from the user
# 2. Convert the word in to list of characters
# 3. Use the reverse function to reverse the words
# 4. print the output of reversed word

# %%
# Scenario 6: A grading system determines whether a student has passed or failed based on their score.
# Write logic to check if a student has passed a subject by scoring at least 40 marks.
# 1. Read the marks
# 2. if mark is greater than or equal to 40
# 3. Print output as "Pass"

# %%
# Scenario 7: A retail store offers a 20% discount if a customer’s total order exceeds $100.
# Write logic to calculate the final amount to be paid after applying the discount.
# 1. Read the total order amount
# 2. Check total amount is exceeds $100
# 3. if yes, calculated the 20% discount
# 4. reduce the calculated 20% amount from total order amount
# 5. return the final amount

# %%
# Scenario 8: A banking system processes withdrawal requests and ensures the user has enough balance.
# Write logic to check if a user has enough balance before allowing a withdrawal and update the remaining balance accordingly.
# 1. Read the available amount in account and withdrawal amount
# 2. if available amount is grater than the withdrawal amount
# 3. reduce the withdrawal amount from total available amount
# 4. return updated available balance
# 5. if withdrawal amount is grater than the available balance
# 6. print user doesn't enough fund

# %%
# Scenario 9: A calendar system verifies whether a given year is a leap year based on standard leap year rules.
# Write logic to determine whether a given year is a leap year.
# 1. Get the year from the user
# 2. Check the given year is divisible by 4, not by 100, leap year
# 3. Check the given year is divisible by 400, leap year
# 4. remaining are not a leap year

# %%
# Scenario 10: A program filters out only even numbers from a given list.
# Write logic to extract and return only the even numbers from a list.
# 1. Read the given list of numbers
# 2. if given number divisible by 2 using the modulo operater
# 3. Check "==" operator to validate the remainder should be 0 
# 4. return the even numbers
