# %%
#1.Find the error in the following Python code:
# ':' was missing in next to range    

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?
#" " need to be removed in values
a = 10
b = 5
print(a + b)
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?
# ':' was missing in next to variables
def add_numbers(a, b):
    return a + b

# %%
#4.Identify the bug in the following Python code:
# as per print we should have 5th degit, it will start from 0
numbers = [1, 2, 3, 4, 5]
print(numbers[4])
# Out:
# 5

# %%
#5.Find the error in the following Python code:
# '(' and ')' open and closed parentheses was missing
print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
# number divide by zero is undefined 
x = 5 / 1
print(x)
# Out:
# 5.0

# %%
#7.Find the error in the following Python code:name = "Alice"
#name variable not defined and coma separater missing in front of integer

age = 25
name ="Alice"
print("Name: "+name+", Age: ",age)
# Out:
# Name: Alice, Age:  25

# %%
#8.Find the error
#range start from 0, so it will go up to 9 in positive, we can't give -1 as the step number to define the difference
for i in range(1, 10, 1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#9. Find the error in the following Python code:
# to get output we should provided X value as 5 or need to add else: statement, also we should use "==" assignment operator to get the output
x = 10
if x == 5:
    print("x is 5")

# %%
#10. Identify the error in the following function definition:
# ':' was missing in next to function 
def greet(name):
    print("Hello, " + name)
